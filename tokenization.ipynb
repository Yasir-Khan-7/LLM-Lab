# %% [markdown]
# #Understanding the tokenization

# %%
import tiktoken

# %%
import tiktoken

en = tiktoken.get_encoding("o200k_base")

text = "hello yasir have a great day"


tokens = en.encode(text)
print(tokens)
